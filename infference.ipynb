# %%
import joblib
import pandas as pd

# %% [markdown]
# # 1. Sumur F-12

# %%
dt_F_12=joblib.load('Modeling_F-12')

# %%
F_12 = pd.DataFrame({
    'BORE_WI_VOL': [1000],
    'BORE_WAT_VOL': [5000],
    'BORE_GAS_VOL': [400000],
    'ON_STREAM_HRS': [23.3], 
    'AVG_DOWNHOLE_PRESSURE': [250],
    'AVG_DOWNHOLE_TEMPERATURE': [150],
    'AVG_DP_TUBING': [30.516],
    'AVG_ANNULUS_PRESS': [1100],
    'AVG_WHT_P': [75.1856471397616],
    'DP_CHOKE_SIZE': [1.07964663055255],
    'AVG_CHOKE_SIZE': [89.857433125],
    'AVG_WHP_P': [30.5164660130011]
})



predictions = dt_F_12.predict(F_12)
print(f" Oil Production Predictions: {predictions} MSTB")
# Out:
#  Oil Production Predictions: [2903.27] MSTB

# %% [markdown]
# - mengambil feature data actual terdapat perbedaan hasil prediksi
# - data actual = 500, data prediksi 212
# - terdapat error 42% prediksi lebih rendah

# %% [markdown]
# # 2. Sumur F-14

# %%
dt_F_14=joblib.load('Modeling_F-14')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18020\966157860.py in <cell line: 1>()
# ----> 1 dt_F_14=joblib.load('Modeling_F-14')
#
# c:\Users\User\anaconda3\envs\h8_env\lib\site-packages\joblib\numpy_pickle.py in load(filename, mmap_mode, ensure_native_byte_order)
#     733             obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734     else:
# --> 735         with open(filename, "rb") as f:
#     736             with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737                 fobj,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Modeling_F-14'

# %%
F_14 = pd.DataFrame({
    'BORE_WI_VOL': [1000],
    'BORE_WAT_VOL': [864],
    'BORE_GAS_VOL': [86.497],
    'ON_STREAM_HRS': [22], 
    'AVG_DOWNHOLE_PRESSURE': [254.206],
    'AVG_DOWNHOLE_TEMPERATURE': [101.904],
    'AVG_DP_TUBING': [202.517],
    'AVG_ANNULUS_PRESS': [19.103],
    'AVG_WHT_P': [75.628],
    'DP_CHOKE_SIZE': [19.77],
    'AVG_CHOKE_SIZE': [33.57],
    'AVG_WHP_P': [52.688]
})




predictions = dt_F_14.predict(F_12)
print(f" Oil Production Predictions: {predictions} MSTB")
# Out:
#  Oil Production Predictions: [262.78] MSTB

# %% [markdown]
# - mengambil feature data actual terdapat perbedaan hasil prediksi
# - data actual = 550, data prediksi 262
# - terdapat error sekitar 50 % prediksi lebih rendah
